# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\jayas\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\jayas\anaconda3\lib\site-packages (from lightgbm) (2.1.3)
# Requirement already satisfied: scipy in c:\users\jayas\anaconda3\lib\site-packages (from lightgbm) (1.15.3)

# %%
import pandas as pd # import library 
import numpy as np
import lightgbm as lgb

# %%
dataset= pd.read_csv("insurance.csv")  # function of pandas used to load the data
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset) #to create dummies value for categorical text
dataset
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400        True     False      False
# 1      18  33.770         1   1725.55230       False      True       True
# 2      28  33.000         3   4449.46200       False      True       True
# 3      33  22.705         0  21984.47061       False      True       True
# 4      32  28.880         0   3866.85520       False      True       True
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830       False      True       True
# 1334   18  31.920         0   2205.98080        True     False       True
# 1335   18  36.850         0   1629.83350        True     False       True
# 1336   21  25.800         0   2007.94500        True     False       True
# 1337   61  29.070         0  29141.36030        True     False      False
#
#       smoker_yes
# 0           True
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 1333       False
# 1334       False
# 1335       False
# 1336       False
# 1337        True
#
# [1338 rows x 8 columns]

# %%
dataset=dataset.replace({True:1,False:0}) #replce the 0 and 1 for true,false
dataset
# Out:
# C:\Users\jayas\AppData\Local\Temp\ipykernel_14068\2063786219.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset=dataset.replace({True:1,False:0}) #replce the 0 and 1 for true,false
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 1333           0
# 1334           0
# 1335           0
# 1336           0
# 1337           1
#
# [1338 rows x 8 columns]

# %%
dataset = dataset.drop(columns=["sex_female", "smoker_no"])# drop columns from the dataset
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]  # split input and output to get input from dataset 
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']] # get output from dataset
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV # built model for grid search and cross validation
param_grid={'random_state':[10,15],'n_estimators':[10,20],'learning_rate':[0.05,0.1,0.01]}
grid= GridSearchCV(XGBRegressor(),param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None,
#                                     lear...one,
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.05, 0.1, 0.01],
#                          'n_estimators': [10, 20], 'random_state': [10, 15]},
#              verbose=3)

# %%
re=grid.cv_results_ # print best parameter after tuning
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'learning_rate': 0.1, 'n_estimators': 20, 'random_state': 10}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.037005      0.011078         0.011900        0.004082
# 1        0.050882      0.005109         0.014433        0.000578
# 2        0.072173      0.005973         0.011840        0.001764
# 3        0.074274      0.008751         0.015521        0.001517
# 4        0.053453      0.004978         0.013934        0.002250
# 5        0.047782      0.002379         0.012919        0.002592
# 6        0.080175      0.003871         0.013924        0.001700
# 7        0.074450      0.005201         0.014209        0.001353
# 8        0.051067      0.001812         0.013667        0.000531
# 9        0.052023      0.001628         0.013738        0.000837
# 10       0.074682      0.004883         0.013248        0.001003
# 11       0.070543      0.006491         0.012620        0.001804
#
#     param_learning_rate  param_n_estimators  param_random_state  \
# 0                  0.05                  10                  10
# 1                  0.05                  10                  15
# 2                  0.05                  20                  10
# 3                  0.05                  20                  15
# 4                  0.10                  10                  10
# 5                  0.10                  10                  15
# 6                  0.10                  20                  10
# 7                  0.10                  20                  15
# 8                  0.01                  10                  10
# 9                  0.01                  10                  15
# 10                 0.01                  20                  10
# 11                 0.01                  20                  15
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 0.05, 'n_estimators': 10, 'r...           0.555984
# 1   {'learning_rate': 0.05, 'n_estimators': 10, 'r...           0.555984
# 2   {'learning_rate': 0.05, 'n_estimators': 20, 'r...           0.760775
# 3   {'learning_rate': 0.05, 'n_estimators': 20, 'r...           0.760775
# 4   {'learning_rate': 0.1, 'n_estimators': 10, 'ra...           0.767967
# 5   {'learning_rate': 0.1, 'n_estimators': 10, 'ra...           0.767967
# 6   {'learning_rate': 0.1, 'n_estimators': 20, 'ra...           0.859047
# 7   {'learning_rate': 0.1, 'n_estimators': 20, 'ra...           0.859047
# 8   {'learning_rate': 0.01, 'n_estimators': 10, 'r...           0.156117
# 9   {'learning_rate': 0.01, 'n_estimators': 10, 'r...           0.156117
# 10  {'learning_rate': 0.01, 'n_estimators': 20, 'r...           0.284825
# 11  {'learning_rate': 0.01, 'n_estimators': 20, 'r...           0.284825
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.526958           0.538178           0.547605
# 1            0.526958           0.538178           0.547605
# 2            0.711472           0.744963           0.738740
# 3            0.711472           0.744963           0.738740
# 4            0.717526           0.751604           0.745283
# 5            0.717526           0.751604           0.745283
# 6            0.796930           0.862387           0.830116
# 7            0.796930           0.862387           0.830116
# 8            0.148994           0.149096           0.156087
# 9            0.148994           0.149096           0.156087
# 10           0.272100           0.273910           0.283357
# 11           0.272100           0.273910           0.283357
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.543633         0.542471        0.009689                7
# 1            0.543633         0.542471        0.009689                7
# 2            0.743440         0.739878        0.016021                5
# 3            0.743440         0.739878        0.016021                5
# 4            0.748974         0.746271        0.016332                3
# 5            0.748974         0.746271        0.016332                3
# 6            0.845026         0.838701        0.023806                1
# 7            0.845026         0.838701        0.023806                1
# 8            0.152770         0.152613        0.003157               11
# 9            0.152770         0.152613        0.003157               11
# 10           0.277745         0.278388        0.005023                9
# 11           0.277745         0.278388        0.005023                9

# %%
import pickle   # store the model
filename = "finalized_model_XG_BOOST_grid.sav" 
pickle.dump(grid,open(filename,"wb"))

# %%
load_model=pickle.load(open("finalized_model_XG_BOOST_grid.sav" ,"rb")) # load the model from the file
result=load_model.predict([[50,30.970,3,1,0]])

# %%
result
# Out:
# array([11973.082], dtype=float32)
